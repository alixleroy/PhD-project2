# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import scipy.stats as stats

# %%
with open('1_steps_considered_time_1438.648771762848.csv', 'rb') as file:
    alphalist1 = pickle.load(file)
with open('2_steps_considered_time_1668.6826422214508.csv', 'rb') as file:
    alphalist2 = pickle.load(file)
with open('6_steps_considered_time_2431.4907813072205.csv', 'rb') as file:
    alphalist6 = pickle.load(file)
with open('10_steps_considered_time_3139.3462188243866.csv', 'rb') as file:
    alphalist10 = pickle.load(file)
with open('14_steps_considered_time_3975.9966402053833.csv', 'rb') as file:
    alphalist14 = pickle.load(file)
with open('18_steps_considered_time_4496.125002861023.csv', 'rb') as file:
    alphalist18 = pickle.load(file)
with open('22_steps_considered_time_5374.013044834137.csv', 'rb') as file:
    alphalist22 = pickle.load(file)
with open('26_steps_considered_time_6817.443048238754.csv', 'rb') as file:
    alphalist26 = pickle.load(file)

# %%
fig, ax = plt.subplots(figsize=(40,30))

mu = 0
sigma = 1
x = np.linspace(-2,1.3, 100)
ax.plot(x, stats.norm.pdf(x, mu, sigma), linewidth=7, color='C7', label=r'$P(\alpha)$', zorder=0)

#ax.hist(alphalist1, 50, stacked=True, density=True, label='1 snapshot')
#ax.hist(alphalist2, 50, stacked=True, density=True, label='2 snapshots')
#ax.hist(alphalist6, 50, stacked=True, density=True, label='6 snapshots')
#ax.hist(alphalist10, 50, stacked=True, density=True, label='10 snapshots')
#ax.hist(alphalist14, 50, stacked=True, density=True, label='14 snapshots')
#ax.hist(alphalist18, 50, stacked=True, density=True, label='18 snapshots')
#ax.hist(alphalist22, 50, stacked=True, density=True, label='22 snapshots')
#ax.hist(alphalist26, 50, stacked=True, density=True, label='26 snapshots', color='C3')
ax.set_ylim(0,5)
#ax.axvline(x=0,linewidth=7, linestyle='--', color='black', label=r'$\alpha^*$')
ax.legend(prop={'size': 50})
ax.set_title(r'Sampling Distribution of $\alpha$ After 1000 RWMH Iterations', fontsize=60)
ax.set_title(r'Prior on $\alpha$', fontsize=60)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.ylabel(r'$P(\alpha\mid y)$', fontsize=80)
plt.ylabel(r'$P(\alpha)$', fontsize=80)
plt.xlabel(r'$\alpha$', fontsize=80)
ax.set_xlim(-2,1.3)
# Out:
# (-2.0, 1.3)
